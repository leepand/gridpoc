# %%
# %%file custom_add.html
# <head>
#     <script src="../static/js/custom.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
#
#
#     <!-- Contents -->
#     <div id="Contents">
#         <div id="MainForm">
#             <h2><div style="color:#169c83">添加客户</div></h2>
#         <div id="Popup">
#             <div id="SubPopup">
#                 <div class="form_boxC">
#                     <p class="f_cB pdg_t5">提示：带"<span class="f_cB">*</span>"号为必填项</p>
#                     <table cellpadding="0" cellspacing="0">
#                         <tr>
#                             <th width="100">开发者姓名 <span class="f_cB">*</span></th>
#                             <td><div class="txtbox floatL" style="width:150px;"><input id="form_name" name="" type="text" size="12" value=""></div></td>
#                         </tr>
#                         <tr>
#                             <th>联系地址 <span class="f_cB">*</span></th>
#                             <td><div class="txtbox floatL" style="width:300px;"><input id="form_address" name="" type="text" size="30" value=""></div></td>
#                         </tr>
#                         <tr>
#                             <th>联系电话 <span class="f_cB">*</span></th>
#                             <td><div class="txtbox floatL" style="width:150px;"><input id="form_phone" name="" type="text" size="12" value=""></div></td>
#                         </tr>
#                         <tr>
#                             <th>开发者类型 <span class="f_cB">*</span></th>
#                             <td><!-- selectbox -->
#                                 <div class="selectbox" style="width:230px;">
#                                     <dl class="select">
#                                         <dt class="ctype">选择（新/老）</dt>
#                                         <dd><ul>
#                                             <li><a href="#">新</a></li>
#                                             <li><a href="#">老</a></li>
#                                         </ul></dd></dl>
#                                 </div>
#                                 <!-- /selectbox --></td>
#                         </tr>
#                         <tr>
#                             <th>开发者等级 <span class="f_cB">*</span></th>
#                             <td><!-- selectbox -->
#                                 <div class="selectbox" style="width:230px;">
#                                     <dl class="select">
#                                         <dt class="class_priv">选择（A/B/C）</dt>
#                                         <dd><ul>
#                                             <li><a href="#"> A </a></li>
#                                             <li><a href="#"> B </a></li>
#                                             <li><a href="#"> C </a></li>
#                                         </ul></dd></dl>
#                                 </div>
#                                 <!-- /selectbox --></td>
#                         </tr>
#                         <tr>
#                             <th>开发者状态 <span class="f_cB">*</span></th>
#                             <td><!-- selectbox -->
#                                 <div class="selectbox" style="width:230px;">
#                                     <dl class="select">
#                                         <dt class="status">选择（正常/取消）</dt>
#                                         <dd><ul>
#                                             <li><a href="#">正常</a></li>
#                                             <li><a href="#">取消</a></li>
#                                         </ul></dd></dl>
#                                 </div>
#                                 <!-- /selectbox --></td>
#                         </tr>
#
#
#                         <tr>
#                             <th>备注</th>
#                             <td><div class="txtbox"><textarea id="form_remark" name="" cols="35" rows="2"></textarea></div><p class="f_cB pdg_t5">该项可不填，最多50字</p></td>
#                         </tr>
#                     </table>
#                 </div>
#             </div>
#             <!-- SubPopup -->
#
#             <div id="BtmBtn">
#                 <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#                 <div class="btn_box floatR"><input name="" type="button" value="提交" onclick=add_custom() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#             </div>
#         </div>
#         </div>
#                 <!-- /Popup -->
#                 <!-- /Contents -->
# Out:
# Writing custom_add.html

# %%
# %%file custom_edit.html
# <!DOCTYPE HTML>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title></title>
#     <meta name="keywords" content="" />
#     <meta name="description" content="" />
#     <meta name="generator" content="" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;">
#     <link href="../static/css/haiersoft.css" rel="stylesheet" type="text/css" media="screen,print" />
#     <link href="../static/css/print.css" rel="stylesheet" type="text/css"  media="print" />
#     <script src="../static/js/jquery-1.10.1.min.js"></script>
#     <script src="../static/js/side.js" type="text/javascript"></script>
#     <script src="../static/js/custom.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
# <body>
# <!-- Popup -->
# <div id="Popup">
#
# <script type="text/javascript">
#     $$(document).ready(function(){
#         get_custom_info();
#     });
# </script>
#
#     <!-- SubPopup -->
#     <div id="SubPopup">
#         <div class="form_boxC">
#             <p>提示：带"<span class="f_cB">*</span>"号为必填项目</p>
#             <table cellpadding="0" cellspacing="0">
#                 <p id="form_cid" hidden="hidden">cid</p>
#                 <tr>
#                     <th>姓名 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:150px;"><input id="form_name" name="" type="text" size="12" value=""></div></td>
#
#                 </tr>
#                 <tr>
#                     <th>地址 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:310px;"><input id="form_address" name="" type="text" size="30" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>电话 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:150px;"><input id="form_phone" name="" type="text" size="12" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>开发者类型 <span class="f_cB">*</span></th>
#                     <td><!-- selectbox -->
#                         <div class="selectbox" style="width:230px;">
#                             <dl class="select">
#                                 <dt class="ctype">选择（新/老）</dt>
#                                 <dd><ul>
#                                     <li><a href="#">新</a></li>
#                                     <li><a href="#">老</a></li>
#                                 </ul></dd></dl>
#                         </div>
#                         <!-- /selectbox --></td>
#                 </tr>
#                 <tr>
#                     <th>开发者等级 <span class="f_cB">*</span></th>
#                     <td><!-- selectbox -->
#                         <div class="selectbox" style="width:230px;">
#                             <dl class="select">
#                                 <dt class="class_priv">选择（A/B/C）</dt>
#                                 <dd><ul>
#                                     <li><a href="#">A</a></li>
#                                     <li><a href="#">B</a></li>
#                                     <li><a href="#">C</a></li>
#                                 </ul></dd></dl>
#                         </div>
#                         <!-- /selectbox --></td>
#                 </tr>
#                 <tr>
#                     <th>开发者状态 <span class="f_cB">*</span></th>
#                     <td><!-- selectbox -->
#                         <div class="selectbox" style="width:230px;">
#                             <dl class="select">
#                                 <dt class="status">选择（正常/取消）</dt>
#                                 <dd><ul>
#                                     <li><a href="#">正常</a></li>
#                                     <li><a href="#">取消</a></li>
#                                 </ul></dd></dl>
#                         </div>
#                         <!-- /selectbox --></td>
#                 </tr>
#                 <tr>
#                     <th>备注 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:310px;"><input id="form_remark" name="" type="text" size="30" value=""></div></td>
#                 </tr>
#             </table>
#         </div>
#         <div id="BtmBtn">
#             <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#             <div class="btn_box floatR"><input name="" type="button" onclick=update_custom_info() value="提交" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#         </div>
#     </div>
#     <!-- SubPopup -->
#
#
# </div>
# <!-- /Popup -->
# </body>
# </html>
# Out:
# Overwriting custom_edit.html

# %%
# %%file custom_list.html
# <head>
#     <script src="../static/js/layer/layer.js" type="text/javascript"></script>
#     <script src="../static/js/side.js" type="text/javascript"></script>
#     <script src="../static/js/popwin.js" type="text/javascript"></script>
#     <script src="../static/js/custom.js" type="text/javascript"></script>
#     <script src="../static/js/order.js" type="text/javascript"></script>
# </head>
#     <!-- Contents -->
#     <div id="Contents">
#         <div id="MainForm">
#             <h2><div style="color:#169c83">开发者列表 <div class="btn_box floatR"><input type="button" value="导出到Excel文件" onclick=export_custom_list() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div></div></h2>
#             <div class="form_boxA">
#                 <table cellpadding="0" cellspacing="0">
#                     <tr>
#                         <th>开发者ID</th>
#                         <th>开发者姓名</th>
#                         <th>联系地址</th>
#                         <th>电话</th>
#                         <th>开发者类型</th>
#                         <th>开发者等级</th>
#                         <th>开发者状态</th>
#                         <th>备注</th>
#                         <th>添加时间</th>
#                         <th>执行相关操作</th>
#                     </tr>
#                     <script type="text/javascript">
#                         $$(document).ready(function(){
#                             get_custom_list();
#                         });
#                     </script>
#
#
#
#
#                 </table>
#                 <p class="msg">共找到<span id="data_count">0</span>条记录</p>
#             </div>
#         </div>
#
#         <!-- PageNum -->
#         <ul id="PageNum">
#             <li><a href="">首页</a></li>
#             <li><a href="">上一页</a></li>
#             <li><a href="">1</a></li>
#             <li><a href="">2</a></li>
#             <li><a href="">3</a></li>
#             <li><a href="">4</a></li>
#             <li><a href="">5</a></li>
#             <li><a href="">6</a></li>
#             <li><a href="">下一页</a></li>
#             <li><a href="">尾页</a></li>
#         </ul>
#         <!-- /PageNum -->
#     </div>
#     <!-- /Contents -->
# Out:
# Overwriting custom_list.html

# %%
# %%file custom_search.html
# <head>
# <script src="../static/js/popwin.js" type="text/javascript"></script>
# <script src="../static/js/custom.js" type="text/javascript"></script>
# <script src="../static/js/order.js" type="text/javascript"></script>>
# <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
#
# <!-- Contents -->
# <div id="Contents">
#
# <!-- TopMain -->
# <div id="TopMain">
# <!-- selectbox -->
# <div class="selectbox mag_r20 floatL">
#     <span class="sttl">客户状态：</span>
#     <dl class="select" style="width:100px;">
#         <dt class="search_status">全部</dt>
#         <dd><ul>
#             <li><a href="#">全部</a></li>
#             <li><a href="#">正常</a></li>
#             <li><a href="#">已删除</a></li>
#     </ul></dd></dl>
# </div>
# <!-- /selectbox -->
#
# <!-- textbox -->
# <div class="txtbox floatL mag_r20">
# <span class="sttl">模糊查找：</span>
# <input id="search_data" type="text" size="20" placeholder="姓名/地址/电话">
# </div>
# <!-- /textbox -->
# <div class="btn_box floatL"><input type="button" value="查找" onclick=search_custom_list() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# </div>
# <!-- /TopMain -->
#
# <!-- MainForm -->
# <div id="MainForm">
# <div class="form_boxA">
#     <h2><div style="color:#169c83">找到匹配客户数据：</div></h2>
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th>客户号</th>
# <th>姓名</th>
# <th>联系地址</th>
# <th>电话</th>
# <th>客户类型</th>
# <th>客户等级</th>
# <th>客户状态</th>
# <th>备注</th>
# <th>添加时间</th>
# <th>操作</th>
# </tr>
#
# </table>
# <p class="msg">共找到<span id="data_count">0</span>条记录</p>
# </div>
# </div>
# <!-- /MainForm -->
# </div>
# <!-- /Contents -->
# Out:
# Writing custom_search.html

# %%
# %%file order_add.html
# <head>
#     <script src="../static/js/order.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
# <!-- Contents -->
# <div id="Contents">
#     <div id="MainForm">
#     <h2><div style="color:#169c83">添加新上线API</div></h2>
# <div id="Popup">
# <div id="SubPopup">
#
# <div class="form_boxC">
# <p class="f_cB pdg_t5">提示：带"<span class="f_cB">*</span>"号为必填项</p>
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th width="100">开发者ID <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_cid" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th width="100">API类型 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_otype" name="" type="text" size="12" value=""></div></td>
# </tr>
#
# <tr>
# <th width="100">上线时间 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_order_tm" name="" type="text" size="12" value=""></div></td>
# </tr>
#
# <tr>
# <th width="100">备注 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_remark" name="" type="text" size="12" value=""></div></td>
# </tr>
# </table>
# </div>
# </div>
# <!-- SubPopup -->
#
# <div id="BtmBtn">
#             <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#             <div class="btn_box floatR"><input name="" type="button" onclick=add_order_info() value="提交" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# </div>
#
# <!-- <div id="BtmBtn">
# <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# <div class="btn_box floatR"><input name="" type="button" value="添加" onclick=add_user() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# </div>-->
# </div>
# </div>
# <!-- /Popup -->
# <!-- /Contents -->
# Out:
# Writing order_add.html

# %%
# %%file order_all.html
# <head>
# <script src="../static/js/popwin.js" type="text/javascript"></script>
# <script src="../static/js/order.js" type="text/javascript"></script>
# </head>
#
# <!-- Contents -->
# <div id="Contents">
# <div id="MainForm">
#     <h2><div style="color:#169c83">服务列表<div class="btn_box floatR"><input type="button" value="导出到Excel文件" onclick=export_order_list() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div></div></h2>
# <div class="form_boxA">
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th>APIID</th>
# <th>开发者ID</th>
# <th>开发者姓名</th>
# <th>API类型</th>
# <th>上线时间</th>
# <!--<th>送奶开始</th>
# <th>送奶结束</th>-->
# <!--<th>价格</th>-->
# <!--<th>实收</th>-->
# <th>API状态</th>
# <th>备注</th>
# <th>添加时间</th>
# <th>执行操作</th>
# </tr>
#
# <script type="text/javascript">
# $$(document).ready(function(){
#     get_order_list();
#
# });
# </script>
#
# </table>
# <p class="msg">共找到<span id="data_count">0</span>条记录</p>
# </div>
# </div>
#
# <!-- PageNum -->
# <ul id="PageNum">
# <li><a href="">首页</a></li>
# <li><a href="">上一页</a></li>
# <li><a href="">1</a></li>
# <li><a href="">2</a></li>
# <li><a href="">3</a></li>
# <li><a href="">4</a></li>
# <li><a href="">5</a></li>
# <li><a href="">6</a></li>
# <li><a href="">下一页</a></li>
# <li><a href="">尾页</a></li>
# </ul>
# <!-- /PageNum -->
# </div>
# <!-- /Contents -->
# Out:
# Overwriting order_all.html

# %%
# %%file order_cancel.html
# <head>
#     <script src="../static/js/custom.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
#     <script src="../static/js/order.js" type="text/javascript"></script>
# </head>
#
# <!-- Contents -->
# <div id="Contents">
# <div id="MainForm">
#     <h2><div style="color:#169c83">已取消服务</div></h2>
# <div class="form_boxA">
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th>APIID</th>
# <th>开发者ID</th>
# <th>开发者姓名</th>
# <!-- <th>地址</th>-->
# <!-- <th>电话</th>-->
# <th>API类型</th>
# <!-- <th>客户等级</th>-->
# <th>添加时间</th>
# <th>API状态</th>
# <th>备注</th>
# <th>操作时间</th>
# </tr>
# <script type="text/javascript">
# $$(document).ready(function(){
#     get_order_cancel_list();
# });
# </script>
# </table>
# <p class="msg">共找到<span id="data_count">0</span>条记录</p>
# </div>
# </div>
#
# <!-- PageNum -->
# <ul id="PageNum">
# <li><a href="">首页</a></li>
# <li><a href="">上一页</a></li>
# <li><a href="">1</a></li>
# <li><a href="">2</a></li>
# <li><a href="">3</a></li>
# <li><a href="">4</a></li>
# <li><a href="">5</a></li>
# <li><a href="">6</a></li>
# <li><a href="">下一页</a></li>
# <li><a href="">尾页</a></li>
# </ul>
# <!-- /PageNum -->
# </div>
# <!-- /Contents -->
# Out:
# Overwriting order_cancel.html

# %%
# %%file order_edit.html
# <!DOCTYPE HTML>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title></title>
#     <meta name="keywords" content="" />
#     <meta name="description" content="" />
#     <meta name="generator" content="" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;">
#     <link href="../static/css/haiersoft.css" rel="stylesheet" type="text/css" media="screen,print" />
#     <link href="../static/css/print.css" rel="stylesheet" type="text/css"  media="print" />
#     <script src="../static/js/jquery-1.10.1.min.js"></script>
#     <script src="../static/js/side.js" type="text/javascript"></script>
#     <script src="../static/js/order.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
# <body>
# <!-- Popup -->
# <div id="Popup">
#
# <script type="text/javascript">
#     $$(document).ready(function(){
#         get_order_info();
#     });
# </script>
#
#     <!-- SubPopup -->
#     <div id="SubPopup">
#         <div class="form_boxC">
#             <p>提示：带"<span class="f_cB">*</span>"号为必填项目</p>
#             <table cellpadding="0" cellspacing="0">
#                 <p id="form_oid" hidden="hidden">oid</p>
#                 <tr>
#                     <th>开发者姓名 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:150px;"><input id="form_name" name="" type="text" disabled="true" size="12" value=""></div></td>
#
#                 </tr>
#
#                 <tr>
#                     <th>API类型 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:150px;"><input id="form_otype" name="" type="text" size="12" value=""></div></td>
#
#                 </tr>
#               <tr>
#                     <th>上线时间 <span class="f_cB">*</span></th>
#                         <td><div class="txtbox floatL" style="width:150px;"><input id="form_order_tm" name="" type="text" size="12" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>API状态 <span class="f_cB">*</span></th>
#                 <td><!-- selectbox -->
#                     <div class="selectbox" style="width:230px;">
#                         <dl class="select">
#                         <dt class="status">选择（正常/已取消）</dt>
#                         <dd><ul>
#                             <li><a href="#">正常</a></li>
#                             <li><a href="#">已取消</a></li>
#                         </ul></dd></dl>
#                     </div>
#                 <!-- /selectbox --></td>
#                 </tr>
#                 <tr>
#                     <th>备注 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:310px;"><input id="form_remark" name="" type="text" size="30" value=""></div></td>
#                 </tr>
#             </table>
#         </div>
#         <div id="BtmBtn">
#             <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#             <div class="btn_box floatR"><input name="" type="button" onclick=update_order_info() value="提交" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#         </div>
#     </div>
#     <!-- SubPopup -->
#
#
# </div>
# <!-- /Popup -->
# </body>
# </html>
# Out:
# Overwriting order_edit.html

# %%
# %%file order_search.html
# <head>
# <script src="../static/js/popwin.js" type="text/javascript"></script>
# <script src="../static/js/custom.js" type="text/javascript"></script>
# <script src="../static/js/order.js" type="text/javascript"></script>
# </head>
#
# <!-- Contents -->
# <div id="Contents">
#
# <!-- TopMain -->
# <div id="TopMain">
#
# <!-- selectbox -->
# <div class="selectbox mag_r20 floatL">
#     <span class="sttl">API状态：</span>
#     <dl class="select" style="width:100px;">
#         <dt class="search_status">全部</dt>
#         <dd><ul>
#             <li><a href="#">全部</a></li>
#             <li><a href="#">正常</a></li>
#             <li><a href="#">已取消</a></li>
#     </ul></dd></dl>
# </div>
# <!-- /selectbox -->
#
# <!-- textbox -->
# <div class="txtbox floatL mag_r20">
# <span class="sttl">模糊查找：</span>
# <input id="search_data" type="text" size="20" placeholder="开发者ID/姓名">
# </div>
# <!-- /textbox -->
# <div class="btn_box floatL"><input name="" type="button" value="查找" onclick=search_order_list() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# </div>
# <!-- /TopMain -->
#
# <!-- MainForm -->
# <div id="MainForm">
# <div class="form_boxA">
#     <h2><div style="color:#169c83">找到匹配客户数据：</div></h2>
# <table cellpadding="0" cellspacing="0">
#     <tr>
#         <th>APIID</th>
#         <th>开发者ID</th>
#         <th>开发者姓名</th>
#         <th>API类型</th>
#         <th>上线时间</th>
#         <!--<th>送奶开始</th>-->
#         <!--<th>送奶结束</th>-->
#         <!--<th>价格</th>-->
#         <!--<th>实收</th>-->
#         <th>API状态</th>
#         <th>备注</th>
#         <th>添加时间</th>
#         <th>执行操作</th>
#     </tr>
# </table>
# <p class="msg">共找到<span id="data_count">0</span>条记录</p>
# </div>
# </div>
# <!-- /MainForm -->
# </div>
# <!-- /Contents -->
# Out:
# Writing order_search.html

# %%
# %%file order_today.html
# <head>
# <script src="../static/js/order_today.js" type="text/javascript"></script>
# </head>
# <!-- Contents -->
# <div id="Contents">
# <div id="MainForm">
#     <h2><div style="color:#169c83">今日API列表
#             <script language="javascript">
#                 var d = new Date();
#                 var date = d.getDate();
#                 var month = d.getMonth()+1;
#                 var today = "("+ month + "月" + date +"日)";
#                 document.write(today);
#             </script>
#     <div class="btn_box floatR"><input type="button" value="导出到Excel文件" onclick=export_order_today() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#     </div></h2>
# <div class="form_boxA">
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th>APIID</th>
# <th>开发者ID</th>
# <th>开发者姓名</th>
# <!--<th>配送地址</th>-->
# <!--<th>联系电话</th>-->
# <th>API类型</th>
# <th>上线时间</th>
# <!--<th>客户类型</th>-->
# <th>API状态</th>
# <th>备注</th>
# <th>操作</th>
# </tr>
#
# <script type="text/javascript">
#     $$(document).ready(function() {
#     get_order_today();
#
# });
# </script>
#
# </table>
# <p class="msg">共找到<span id="data_count">0</span>条记录</p>
# </div>
# </div>
#
# <!-- PageNum -->
# <ul id="PageNum">
# <li><a href="">首页</a></li>
# <li><a href="">上一页</a></li>
# <li><a href="">1</a></li>
# <li><a href="">2</a></li>
# <li><a href="">3</a></li>
# <li><a href="">4</a></li>
# <li><a href="">5</a></li>
# <li><a href="">6</a></li>
# <li><a href="">下一页</a></li>
# <li><a href="">尾页</a></li>
# </ul>
# <!-- /PageNum -->
# </div>
# <!-- /Contents -->
# Out:
# Writing order_today.html

# %%
# %%file user_add.html
# <head>
# <script src="../static/js/user.js" type="text/javascript"></script>
# </head>
# <!-- Contents -->
# <div id="Contents">
#     <div id="MainForm">
#     <h2><div style="color:#169c83">添加系统用户</div></h2>
# <div id="Popup">
# <div id="SubPopup">
#
# <div class="form_boxC">
# <p class="f_cB pdg_t5">提示：带"<span class="f_cB">*</span>"号为必填项</p>
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th width="100">用户姓名 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_nickname" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th width="100">用户名 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_username" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th width="100">用户密码 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_password" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th>联系电话 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_phone" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th>联系邮箱 <span class="f_cB">*</span></th>
# <td><div class="txtbox floatL" style="width:150px;"><input id="form_email" name="" type="text" size="12" value=""></div></td>
# </tr>
# <tr>
# <th>用户类型 <span class="f_cB">*</span></th>
# <td><!-- selectbox -->
# <div class="selectbox" style="width:230px;">
# <dl class="select">
# <dt>选择（管理/运营/访客）</dt>
# <dd><ul>
# <li><a href="#">管理</a></li>
# <li><a href="#">运营</a></li>
# <li><a href="#">访客</a></li>
# </ul></dd></dl>
# </div>
# <!-- /selectbox --></td>
# </tr>
# </table>
# </div>
# </div>
# <!-- SubPopup -->
#
# <div id="BtmBtn">
# <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# <div class="btn_box floatR"><input name="" type="button" value="添加" onclick=add_user() onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
# </div>
# </div>
# </div>
# <!-- /Popup -->
# <!-- /Contents -->
# Out:
# Writing user_add.html

# %%
# %%file user_edit.html
# <!DOCTYPE HTML>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title></title>
#     <meta name="keywords" content="" />
#     <meta name="description" content="" />
#     <meta name="generator" content="" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;">
#     <link href="../static/css/haiersoft.css" rel="stylesheet" type="text/css" media="screen,print" />
#     <link href="../static/css/print.css" rel="stylesheet" type="text/css"  media="print" />
#     <script src="../static/js/jquery-1.10.1.min.js"></script>
#     <script src="../static/js/side.js" type="text/javascript"></script>
#     <script src="../static/js/user.js" type="text/javascript"></script>
#     <script src="../static/js/others.js" type="text/javascript"></script>
# </head>
#
# <body>
# <script type="text/javascript">
# $$(document).ready(function() {
#     get_user_info();
# });
# </script>
#
#
#
#
# <!-- Popup -->
# <div id="Popup">
#
#     <!-- SubPopup -->
#     <div id="SubPopup">
#         <div class="form_boxC">
#             <p>提示：带"<span class="f_cB">*</span>"号为必填项目</p>
#             <table cellpadding="0" cellspacing="0">
#                 <p id="form_uid" hidden="hidden">uid</p>
#                 <tr>
#                     <th>用户姓名 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:130px;"><input id="form_nickname" name="" type="text" size="10" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>用户名 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:130px;"><input id="form_username" name="" type="text" size="10" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>用户密码 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:130px;"><input id="form_password" name="" type="text" size="10" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>手机号 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:130px;"><input id="form_phone" name="" type="text" size="10" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>联系邮箱 <span class="f_cB">*</span></th>
#                     <td><div class="txtbox floatL" style="width:190px;"><input id="form_email" name="" type="text" size="16" value=""></div></td>
#                 </tr>
#                 <tr>
#                     <th>用户等级 <span class="f_cB">*</span></th>
#                     <td><!-- selectbox -->
#                         <div class="selectbox" style="width:230px;">
#                             <dl class="select">
#                                 <dt>选择（管理/运营/访客）</dt>
#                                 <dd><ul>
#                                     <li><a href="#">管理</a></li>
#                                     <li><a href="#">运营</a></li>
#                                     <li><a href="#">访客</a></li>
#                                 </ul></dd></dl>
#                         </div>
#                         <!-- /selectbox --></td>
#                 </tr>
#
#             </table>
#         </div>
#     </div>
#     <!-- SubPopup -->
#
#     <div id="BtmBtn">
#         <div class="btn_boxB floatR mag_l20"><input name="" type="button" value="取消" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#         <div class="btn_box floatR"><input name="" type="button" onclick=update_user_info() value="提交" onmousemove="this.className='input_move'" onmouseout="this.className='input_out'"></div>
#     </div>
# </div>
# <!-- /Popup -->
# </body>
# </html>
# Out:
# Writing user_edit.html

# %%
# %%file user_list.html
# <head>
# <script src="../static/js/popwin.js" type="text/javascript"></script>
# <script src="../static/js/user.js" type="text/javascript"></script>
# </head>
# <!-- Contents -->
# <div id="Contents">
# <div id="MainForm">
#     <h2><div style="color:#169c83">系统用户列表</div></h2>
# <div class="form_boxA">
# <table cellpadding="0" cellspacing="0">
# <tr>
# <th>用户编号</th>
# <th>姓名</th>
# <th>用户名</th>
# <th>密码</th>
# <th>手机号</th>
# <th>联系邮箱</th>
# <th>用户等级</th>
# <th>上次登录</th>
# <th>操作</th>
# </tr>
#
# <script type="text/javascript">
# $$(document).ready(function() {
#     get_user_list();
# });
# </script>
#
# </table>
# </div>
# </div>
#
# </div>
# <!-- /Contents -->
# Out:
# Writing user_list.html
