# %%
# %%file base.html
# $def with (content)
# <!DOCTYPE HTML>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title></title>
# <meta name="keywords" content="" />
# <meta name="description" content="" />
# <meta name="generator" content="" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;">
# <link href="../static/css/haiersoft.css" rel="stylesheet" type="text/css" media="screen,print" />
# <link href="../static/css/print.css" rel="stylesheet" type="text/css"  media="print" />
# <script src="../static/js/jquery-1.10.1.min.js"></script>
# <script src="../static/js/side.js" type="text/javascript"></script>
# <script src="../static/js/index.js" type="text/javascript"></script>
#
# </head>
#
# <body>
# <!-- wrap_left -->
# <div class="wrap_left" id="frmTitle" name="fmTitle">
# <!-- Logo -->
# <div id="Logo"><span>Arthur</span></div>
# <!-- /Logo -->
#
# <!-- menu_list -->
# <script>
# $$(function() {
#     $$(".menu_list dd");
#     $$(".menu_list dt").click(function(){
#         $$(this).toggleClass("open").next().slideToggle("fast");
#     });
# });
# </script>
# <div class="menu_list">
# <dl>
#
# <dt><span>数据统计</span></dt>
# <dd><a href="index.html" title="">系统数据统计</a>
#
# <dt><span>开发者管理</span></dt>
# <dd><a href="custom_list.html" title="客户列表" class="active">客户列表</a>
# <a href="custom_search.html" title="客户查找">客户查找</a>
# <a href="custom_add.html" title="添加客户">添加客户</a></dd>
#
# <dt><span>服务管理</span></dt>
# <dd><a href="order_all.html" title="所有服务">所有服务</a>
# <a href="order_search.html" title="服务查询">服务查询</a>
# <a href="order_today.html" title="当日服务">当日服务</a>
# <a href="order_cancel.html" title="已取消服务">已取消服务</a>
# <a href="order_add.html" title="添加服务">添加服务</a>
# <a href="order_deploy.html" title="部署服务">部署服务</a></dd>
#
# <dt><span>用户管理</span></dt>
# <dd><a href="user_list.html" title="用户列表">用户列表</a>
# <a href="user_add.html" title="添加用户">添加用户</a></dd>
#
# </dl>
# </div>
# <!-- /menu_list -->
# </div>
# <!-- /wrap_left -->
#
# <!-- picBox -->
# <div class="picBox" onclick="switchSysBar()" id="switchPoint"></div>
# <!-- /picBox -->
#
#
#
# <!-- wrap_right -->
# <div class="wrap_right">
# <header>
# <!-- Header -->
# <div id="Header">
# <!-- Head -->
# <div id="Head">
# <h1 title="Arthur－API管理系统"><img src="/static/images/common/logo2.png" width="200" height="36" alt="Arthur"></h1>
# <script language="javascript">
# function showmenu(id){id.style.visibility = "visible";}
# function hidmenu(){UserList.style.visibility = "hidden";}
# document.onclick = hidmenu;
# </script>
# <div class="user"><a href="javascript:showmenu(UserList)">admin</a>
# <div id="UserList"><a href="/user_list.html">修改</a>
# <a href="/logout">注销</a>
# <a href="/logout">退出</a></div>
# </div>
# </div>
# </div>
# <!-- /Header -->
# </header>
#     <!-- Contents -->
#         $:content
#     <!-- /Contents -->
#
# <!-- /footer -->
# <footer>
# <address>上海丙晟科技有限公司 Copyright &copy; 2018<br>邮箱：pandeng.li@163.com  技术支持：Arthur技术部</address>
# </footer>
# <!-- /footer -->
#
# </div>
# <!-- /wrap_right -->
# </body>
# </html>
# Out:
# Writing base.html

# %%
# %%file index.html
# <!-- Contents -->
# <div id="Contents">
# <div id="MainForm">
# <div class="form_boxA">
# <script type="text/javascript">
#     $$(document).ready(function() {
#         get_data_count();
# });
# </script>
#
#
#
# <h2 style="color:#35b380">客户数据统计</h2>
#
# <p style="margin-left:30px; font-size:18px">历史客户数：　<span id="custom_cnt">?</span></p>
# <p style="margin-left:30px; font-size:18px">正常客户数：　<span id="custom_nor">?</span></p>
# <p style="margin-left:30px; font-size:18px">已删除客户数：　<span id="custom_can">?</span></p>
# </div>
# <div class="form_boxA">
# <h2 style="color:#35b380">API数据统计</h2>
# <p style="margin-left:30px; font-size:18px">历史API数：　<span id="order_cnt">?</span></p>
# <p style="margin-left:30px; font-size:18px">正常API数：　<span id="order_nor">?</span></p>
# <p style="margin-left:30px; font-size:18px">已取消API数：　<span id="order_stop">?</span></p>
# <p style="margin-left:30px; font-size:18px">今日API数：　<span id="order_today">?</span></p>
# <p style="margin-left:30px; font-size:18px">今日取消数：　<span id="order_today_stop">?</span></p>
# </div>
# <div class="form_boxA">
# <h2 style="color:#e8482c">到期API权限提醒</h2>
# <p style="margin-left:30px; font-size:18px">3天内到期：共<span id="days_3">?</span></p>
# <p style="margin-left:30px; font-size:18px">7天内到期：共<span id="days_7">?</span></p>
# </div>
# <p class="msg">注意：以上数据统计截止今日（<span id="update_date" style="color:#e8482c">?-?</span>），如有未更新数据请及时更新。</p>
# </div>
# </div>
# <!-- /Contents -->
# Out:
# Writing index.html
